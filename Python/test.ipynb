# %%
a=['x_min','x_max','A','mu','sig']

# for i in range(20):
#     print(a[(i%4)+2])

print(a+8*a[2:])
# Out:
# ['x_min', 'x_max', 'A', 'mu', 'sig', 'A', 'mu', 'sig', 'A', 'mu', 'sig', 'A', 'mu', 'sig', 'A', 'mu', 'sig', 'A', 'mu', 'sig', 'A', 'mu', 'sig', 'A', 'mu', 'sig', 'A', 'mu', 'sig']

# %%
res={'C:\\Users\\jnich\\OneDrive - USherbrooke\\Uni\\PhD\\Data\\micro-PL\\26_08_13\\Data_260813_0_19.txt': {'a0_amplitude': 112.96451190307587, 'a0_decay': 0.48417057229416915}, 'C:\\Users\\jnich\\OneDrive - USherbrooke\\Uni\\PhD\\Data\\micro-PL\\26_08_13\\Data_260813_0_26.txt': {'a0_amplitude': 5.214965933691118, 'a0_decay': 0.7445786292770153}, 'C:\\Users\\jnich\\OneDrive - USherbrooke\\Uni\\PhD\\Data\\micro-PL\\26_08_13\\Data_260813_0_35.txt': {'a0_amplitude': 13.280050789249662, 'a0_decay': 0.8992952679522115}}


combined = {
            param: [res[name][param] for name in res]
            for param in next(iter(res.values()))
    }
print(combined)
# Out:
# {'a0_amplitude': [112.96451190307587, 5.214965933691118, 13.280050789249662], 'a0_decay': [0.48417057229416915, 0.7445786292770153, 0.8992952679522115]}

# %%
import numpy as np
file_path='C:\\Users\\jnich\\OneDrive - USherbrooke\\Uni\\PhD\\Data\\micro-PL\\26_08_13\\Data_260813_0_19.txt'
data=np.genfromtxt(file_path,comments="#",delimiter="\t",encoding="latin-1",names=['a','b','c'])

print(data.names)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 5
#       2 file_path='C:\\Users\\jnich\\OneDrive - USherbrooke\\Uni\\PhD\\Data\\micro-PL\\26_08_13\\Data_260813_0_19.txt'
#       3 data=np.genfromtxt(file_path,comments="#",delimiter="\t",encoding="latin-1",names=['a','b','c'])
# ----> 5 print(data.data.names)
#
# AttributeError: 'memoryview' object has no attribute 'names'

# %%
import matplotlib.pyplot as plt




# 'fig_layout' : {"title": "PL map" ,
#                 "x_axis_label": "x (μm)",
#                 "y_axis_label": "y (μm)",
#                 "z_axis_label": "Counts/s",
xlim=[i for i in "1".split(',')]
print()
if not xlim[0]:
    print('ok')
print(xlim[0])
# fig,ax=plt.subplots()
# ax.plot([1,3],[1,3])
# ax.set_xlim([float(i) for i in "1, 2".split(',')])
# plt.show()
# Out:
# 1

# %%
data_sets={}

class ayo:
    def __init__(self):
        self.name='ayo'
    def __repr__(self):
        return self.name
test=ayo()
print(test)
st='name'

print(getattr(test,st))
# Out:
# ayo
# ayo

# %%
a="abs"


print(a[:-2])
# Out:
# a
